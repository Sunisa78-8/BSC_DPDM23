# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunisa78-8/BSC_DPDM23/blob/main/Frequent_Patterns_(Association_Rules).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GROUP i hate monday
# ### สมาชิก
#         - นางสาวรัตชฎากร นามวงศ์                 รหัส 643020517-1        สไลด์ + present
#         - นางสาวสุชาดา อุปพงษ์                       รหัส 643020524-4      สไลด์ + present
#         - นางสาวธิติพร หิงพุดซา                  รหัส 643021267-3       สไลด์ + present
#         - นางสาวlสุนิสา อุดมขันธุ์                   รหัส 643021278-8        Coding

# %% [markdown]
# ##สไลด์ Pre
# https://www.canva.com/design/DAF5pkX_NJA/dTY8vsC7eWmUJYpQSQoa2Q/edit?utm_content=DAF5pkX_NJA&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/DPDM_DATA_m'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv(os.path.join(path,'/content/drive/MyDrive/DPDM_DATA_m/reduced_marketbasket.csv'),encoding='latin-1')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# Quiz
# มีกี่ประเทศ

# %%
set
# Out:
# set

# %% [markdown]
# ##ทำข้อความเป็นตัวหนา**#แปลง data ให้อยู่ในรูปแบบ Transaction data ด้วย groupby .apply(list)

# %%
data.groupby('InvoiceNo')['StockCode'].apply(list)
# Out:
# InvoiceNo
# 536365     [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# 536366                                        [22633, 22632]
# 536367     [84879, 22745, 22748, 22749, 22310, 84969, 226...
# 536368                          [22960, 22913, 22912, 22914]
# 536369                                               [21756]
#                                  ...
# C581484                                              [23843]
# C581490                                       [22178, 23144]
# C581499                                                  [M]
# C581568                                              [21258]
# C581569                                       [84978, 20979]
# Name: StockCode, Length: 25900, dtype: object

# %%
transactions = data.groupby('InvoiceNo')['StockCode'].apply(list)

# %% [markdown]
# ## Association Rules

# %%
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=122d21e8b7cf6870d3f9ced6fdfe76cd0e0007a0c69e56093c96fe4debc4f687
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
from apyori import apriori

# %%
list(apriori(transactions,min_support = 0.065))
# Out:
# [RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)]),
#  RelationRecord(items=frozenset({'47566'}), support=0.06586872586872587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'47566'}), confidence=0.06586872586872587, lift=1.0)]),
#  RelationRecord(items=frozenset({'85099B'}), support=0.08243243243243244, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.08243243243243244, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.08671814671814672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08671814671814672, lift=1.0)])]

# %%
frequentItemsets = list(apriori(transactions,min_support = 0.065))
frequentItemsets
# Out:
# [RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)]),
#  RelationRecord(items=frozenset({'47566'}), support=0.06586872586872587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'47566'}), confidence=0.06586872586872587, lift=1.0)]),
#  RelationRecord(items=frozenset({'85099B'}), support=0.08243243243243244, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.08243243243243244, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.08671814671814672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08671814671814672, lift=1.0)])]

# %%
len(frequentItemsets)
# Out:
# 4

# %%
frequentItemsets[0]# ไอเทมเซตแรก
# Out:
# RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)])

# %%
frequentItemsets[0][0]
# Out:
# frozenset({'22423'})

# %%
dir(frequentItemsets[0][0])
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'copy',
#  'difference',
#  'intersection',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'symmetric_difference',
#  'union']

# %%
frequentItemsets[0][0].__len__()
# Out:
# 1

# %%
min_sup = 0.03

frequentItemsets = list(apriori(transactions,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'85099B', '22386'}), support=0.03216216216216216, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22386', '85099B'}), confidence=0.03216216216216216, lift=1.0), OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335), OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])
# yes
# ...

# %% [markdown]
# RelationRecord(items=frozenset({'22386', '85099B'}),
#
# support=0.03216216216216216,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22386', '85099B'}), confidence=0.03216216216216216, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335),
#
# OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])

# %%
set(data[(data['StockCode']=='22386') | (data['StockCode']=='85099B') | (data['StockCode']=='22699') | (data['StockCode']=='22697') ]['Description'])
# Out:
# {'GREEN REGENCY TEACUP AND SAUCER',
#  'JUMBO BAG PINK POLKADOT',
#  'JUMBO BAG RED RETROSPOT',
#  'ROSES REGENCY TEACUP AND SAUCER '}

# %% [markdown]
# RelationRecord(items=frozenset({'22699', '22697'}), support=0.03027027027027027,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22699', '22697'}), confidence=0.03027027027027027, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7417218543046358, lift=17.1523178807947),
#
# OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7, lift=17.1523178807947)])

# %% [markdown]
# ##Quiz 22386 และ 85099B คือสินค้าอะไร

# %%
set(data[(data['StockCode']=='22386') | (data['StockCode']=='85099B')]['Description'])
# Out:
# {'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT'}

# %% [markdown]
# #การบ้านจ้า

# %%
data = pd.read_csv(os.path.join(path,'/content/drive/MyDrive/DPDM_DATA_m/reduced_marketbasket.csv'),encoding='latin-1')
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
import pandas as pd
import os

# %%
# !pip install apyori

from apyori import apriori

# %%
#ข้อมูล กี่ประเทศ
data.groupby(['Country']).sum()
# Out:
# <ipython-input-24-417e0038914b>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Country']).sum()
#                       Quantity    UnitPrice    CustomerID
# Country
# Australia                83653     4054.750  1.569300e+07
# Austria                   4827     1701.520  5.021102e+06
# Bahrain                    260       86.570  2.100270e+05
# Belgium                  23152     7540.130  2.571829e+07
# Brazil                     356      142.600  4.086080e+05
# Canada                    2763      910.580  2.615483e+06
# Channel Islands           9479     3738.550  1.128522e+07
# Cyprus                    6317     3920.070  7.715880e+06
# Czech Republic             592       88.150  3.834300e+05
# Denmark                   8188     1266.950  4.876734e+06
# ...

# %% [markdown]
# # HW1 หา Frequent Item Set และ Association Rules
#
# * ของช่วงเวลา Chrhistmas & New Year (1 Dec - 31 Dec)
# * ของประเทศในทวีป Europe
# * ของช่วงเวลาตรุษจีน ในทวีป Asia (15 Jan - 15 Feb)
# * ของช่วงเวลา Chrhistmas & New Year ในทวีป Europe (1 Dec - 31 Dec)
# * ของวันวาเลนไทน์
# * โดยจัดกลุ่มตามประเทศ + เดือน (groupby ประเทศกับเดือน)

# %%
# แปลงรูปแบบเวลาใน  InvoiceDate เป็น  datetime
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

#เแปลงรูปแบบให้เป็น เดือน / วัน / ปี / ชม. / นท.
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'], format='%m/%d/%Y %H:%M')

# สร้างคอลัมน์ 'Date' ดึงข้อมูลเฉพาะ
data['Date'] = data['InvoiceDate'].dt.date
data['Month'] = data['InvoiceDate'].dt.month
data['Year'] = data['InvoiceDate'].dt.year
data['Time'] = data['InvoiceDate'].dt.time
data['Day'] = data['InvoiceDate'].dt.day


data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# ...

# %% [markdown]
# ###ข้อ1. ข้อมูลของช่วงเวลา Chrhistmas & New Year (1 Dec - 31 Dec)

# %%
# ดูช่วงเวลาคริสต์มาสกับปีใหม่
xmas_ny = data[data['Month']==12]
xmas_ny
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# ...

# %%
trans_xny= xmas_ny.groupby('InvoiceNo')['Description'].apply(list).reset_index()
#
trans_xny
# Out:
#      InvoiceNo                                        Description
# 0       536365  [WHITE HANGING HEART T-LIGHT HOLDER, WHITE MET...
# 1       536366  [HAND WARMER UNION JACK, HAND WARMER RED POLKA...
# 2       536367  [ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHO...
# 3       536368  [JAM MAKING SET WITH JARS, RED COAT RACK PARIS...
# 4       536369                         [BATH BUILDING BLOCK WORD]
# ...        ...                                                ...
# 3035   C581484                      [PAPER CRAFT , LITTLE BIRDIE]
# 3036   C581490  [VICTORIAN GLASS HANGING T-LIGHT, ZINC T-LIGHT...
# 3037   C581499                                           [Manual]
# 3038   C581568                       [VICTORIAN SEWING BOX LARGE]
# 3039   C581569  [HANGING HEART JAR T-LIGHT HOLDER, 36 PENCILS ...
#
# [3040 rows x 2 columns]

# %%
PP= trans_xny['Description'].apply(lambda x: [str(item) for item in x])
PP
# Out:
# 0       [WHITE HANGING HEART T-LIGHT HOLDER, WHITE MET...
# 1       [HAND WARMER UNION JACK, HAND WARMER RED POLKA...
# 2       [ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHO...
# 3       [JAM MAKING SET WITH JARS, RED COAT RACK PARIS...
# 4                              [BATH BUILDING BLOCK WORD]
#                               ...
# 3035                        [PAPER CRAFT , LITTLE BIRDIE]
# 3036    [VICTORIAN GLASS HANGING T-LIGHT, ZINC T-LIGHT...
# 3037                                             [Manual]
# 3038                         [VICTORIAN SEWING BOX LARGE]
# 3039    [HANGING HEART JAR T-LIGHT HOLDER, 36 PENCILS ...
# Name: Description, Length: 3040, dtype: object

# %%
##กำหนดค่า min_sup = 0.08

#######ไม่ได้ ปรับถี่ใหม่#########


frequentItem_a = list(apriori(PP,min_support = 0.08))
frequentItem_a
# Out:
# [RelationRecord(items=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS "}), support=0.09243421052631579, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS "}), confidence=0.09243421052631579, lift=1.0)]),
#  RelationRecord(items=frozenset({'REGENCY CAKESTAND 3 TIER'}), support=0.08190789473684211, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'REGENCY CAKESTAND 3 TIER'}), confidence=0.08190789473684211, lift=1.0)]),
#  RelationRecord(items=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.09769736842105263, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.09769736842105263, lift=1.0)])]

# %%
##กำหนดค่า min_sup = 0.035

frequentItem_XN = list(apriori(PP,min_support = 0.035 ))
for i in frequentItem_XN:
    if i[0].__len__()>1:
        print('yes')
        print(i)
#### ตอบบบบ 3 อันก้ได้
# Out:
# yes
# RelationRecord(items=frozenset({'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED '}), support=0.03684210526315789, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED '}), confidence=0.03684210526315789, lift=1.0), OrderedStatistic(items_base=frozenset({'ALARM CLOCK BAKELIKE GREEN'}), items_add=frozenset({'ALARM CLOCK BAKELIKE RED '}), confidence=0.7088607594936708, lift=14.462662475575565), OrderedStatistic(items_base=frozenset({'ALARM CLOCK BAKELIKE RED '}), items_add=frozenset({'ALARM CLOCK BAKELIKE GREEN'}), confidence=0.7516778523489932, lift=14.462662475575565)])
# yes
# ...

# %%
##กำหนดค่า min_sup = 0.035

frequentItem_XN = list(apriori(PP,min_support = 0.035 ))
for i in frequentItem_XN:
    if i[0].__len__()>1:
        print('yes')
        print(i)
#### ตอบบบบ
# Out:
# yes
# RelationRecord(items=frozenset({'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED '}), support=0.03684210526315789, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED '}), confidence=0.03684210526315789, lift=1.0), OrderedStatistic(items_base=frozenset({'ALARM CLOCK BAKELIKE GREEN'}), items_add=frozenset({'ALARM CLOCK BAKELIKE RED '}), confidence=0.7088607594936708, lift=14.462662475575565), OrderedStatistic(items_base=frozenset({'ALARM CLOCK BAKELIKE RED '}), items_add=frozenset({'ALARM CLOCK BAKELIKE GREEN'}), confidence=0.7516778523489932, lift=14.462662475575565)])
# yes
# ...

# %% [markdown]
# *** ตอบ เลือกค่า Suport ที่มากที่สุด คือ
# "PAPER CHAIN KIT 50'S CHRISTMAS "และ 'PAPER CHAIN KIT VINTAGE
# มีconfidence(ค่าสนับสนุน)=0.0477 หรือ 4.77%
#
# - คนซื้อ PAPER CHAIN KIT 50'S CHRISTMAS และก็จะซื้อ PAPER CHAIN KIT VINTAGE CHRISTMAS มี 51.6%
# - คนที่ซื้อ PAPER CHAIN KIT VINTAGE CHRISTMAS แล้วจะซื้อ PAPER CHAIN KIT 50'S CHRISTMAS มี 66.51%

# %% [markdown]
# ##ข้อ2. ของประเทศยุโรป

# %%
europe_countries = data[(data['Country']!='Austria') | (data['Country']!='Belgium')| (data['Country']!='Channel Islands') | (data['Country']!='Cyprus') | (data['Country']!='Czech Republic') | (data['Country']!='Denmark') |
           (data['Country']!='EIRE') | (data['Country']!='European Community')| (data['Country']!='Finland')| (data['Country']!='France') | (data['Country']!='Germany')| (data['Country']!='Greece')|
           (data['Country']!='Iceland') | (data['Country']!='Italy') | (data['Country']!='Lithuania') | (data['Country']!='Malta') | (data['Country']!='Netherlands') | (data['Country']!='Norway') |
           (data['Country']!='Poland') | (data['Country']!='Portugal') | (data['Country']!='Spain') | (data['Country']!='Sweden') | (data['Country']!='Switzerland') | (data['Country']!='United Kingdom')]
europe_countries #แบ่งทวีปยุโรป
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# ...

# %%
a = europe_countries.groupby('InvoiceNo')['Description'].apply(list).reset_index()
trans_europe = a['Description'].apply(lambda x: [str(item) for item in x])

# %%
trans_europe
# Out:
# 0        [WHITE HANGING HEART T-LIGHT HOLDER, WHITE MET...
# 1        [HAND WARMER UNION JACK, HAND WARMER RED POLKA...
# 2        [ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHO...
# 3        [JAM MAKING SET WITH JARS, RED COAT RACK PARIS...
# 4                               [BATH BUILDING BLOCK WORD]
#                                ...
# 25895                        [PAPER CRAFT , LITTLE BIRDIE]
# 25896    [VICTORIAN GLASS HANGING T-LIGHT, ZINC T-LIGHT...
# 25897                                             [Manual]
# 25898                         [VICTORIAN SEWING BOX LARGE]
# 25899    [HANGING HEART JAR T-LIGHT HOLDER, 36 PENCILS ...
# Name: Description, Length: 25900, dtype: object

# %%
min_sup = 0.03

frequentItemsets_Europe = list(apriori(trans_europe, min_support = min_sup))
for i in frequentItemsets_Europe:
    if i[0].__len__()>1:
        print('yes')
        print(i)
        ### ตอบบบ
# Out:
# yes
# RelationRecord(items=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER '}), support=0.03027027027027027, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER '}), confidence=0.03027027027027027, lift=1.0), OrderedStatistic(items_base=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER '}), confidence=0.7417218543046358, lift=17.1523178807947), OrderedStatistic(items_base=frozenset({'ROSES REGENCY TEACUP AND SAUCER '}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.7, lift=17.1523178807947)])
# yes
# ...

# %% [markdown]
# *** ค่า Suport ที่มากที่สุด คือ
# jumbo bag red retrospot และ jumbo bag pink polkadot
# มีconfidence(ค่าสนับสนุน)= 3.22%
#
# - คนที่ซื้อ jumbo bag pink จะซื้อ jumbo bag red มี 67.67%
# - คนที่ซื้อjumbo bag red จะซื้อ  jumbo bag pinkS มี 39.02%

# %% [markdown]
# ##ข้อ 3. ของช่วงเวลาตรุษจีนในทวีป Asia ( 15 Jan - 15 Feb)

# %%
Asia = ['Hong Kong','Bahrain','Israel','Japan','Lebanon','Saudi Arabia','Singapore','United Arab Emirates']

# %%
ASIA_data = data[data['Country']==""]
for i in range(len(Asia)):
  x = data[data['Country']==Asia[i]]
  ASIA_data=pd.concat([x,ASIA_data])
ASIA_data
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 89570     543911     21485    RETROSPOT HEART HOT WATER BOTTLE         6
# 89571     543911     48138                  DOORMAT UNION FLAG         2
# 89572     543911     85150       LADIES & GENTLEMEN METAL SIGN        24
# 89573     543911     82552                 WASHROOM METAL SIGN        24
# 89574     543911     82551              LAUNDRY 15C METAL SIGN        12
# ...          ...       ...                                 ...       ...
# 423776    573154     22452        MEASURING TAPE BABUSHKA PINK        30
# 423777    573154     22492             MINI PAINT SET VINTAGE         36
# 423778    573154     23328  SET 6 SCHOOL MILK BOTTLES IN CRATE         8
# 465423   C576233         M                              Manual        -1
# 465424    576234         M                              Manual         1
#
#                InvoiceDate  UnitPrice  CustomerID               Country  \
# ...

# %%
As_data=ASIA_data[(ASIA_data['Month']==1)]
As_data.head()
# Out:
#       InvoiceNo StockCode                       Description  Quantity  \
# 70758    542102     21519   GIN & TONIC DIET GREETING CARD         72
# 70759    542102     22697   GREEN REGENCY TEACUP AND SAUCER         6
# 70760    542102     22699  ROSES REGENCY TEACUP AND SAUCER          6
# 70761    542102     22343    PARTY PIZZA DISH RED RETROSPOT        24
# 70762    542102     22344    PARTY PIZZA DISH PINK POLKADOT        24
#
#               InvoiceDate  UnitPrice  CustomerID    Country        Date  \
# 70758 2011-01-25 13:26:00       0.36     12744.0  Singapore  2011-01-25
# 70759 2011-01-25 13:26:00       2.95     12744.0  Singapore  2011-01-25
# 70760 2011-01-25 13:26:00       2.95     12744.0  Singapore  2011-01-25
# 70761 2011-01-25 13:26:00       0.21     12744.0  Singapore  2011-01-25
# 70762 2011-01-25 13:26:00       0.21     12744.0  Singapore  2011-01-25
#
#        Month  Year      Time
# 70758      1  2011  13:26:00
# 70759      1  2011  13:26:00
# ...

# %%
As_data2=ASIA_data[(ASIA_data['Month']==2)]
As_data2.head()
# Out:
#       InvoiceNo StockCode                       Description  Quantity  \
# 89570    543911     21485  RETROSPOT HEART HOT WATER BOTTLE         6
# 89571    543911     48138                DOORMAT UNION FLAG         2
# 89572    543911     85150     LADIES & GENTLEMEN METAL SIGN        24
# 89573    543911     82552               WASHROOM METAL SIGN        24
# 89574    543911     82551            LAUNDRY 15C METAL SIGN        12
#
#               InvoiceDate  UnitPrice  CustomerID               Country  \
# 89570 2011-02-14 12:46:00       4.95     17829.0  United Arab Emirates
# 89571 2011-02-14 12:46:00       7.95     17829.0  United Arab Emirates
# 89572 2011-02-14 12:46:00       2.55     17829.0  United Arab Emirates
# 89573 2011-02-14 12:46:00       1.45     17829.0  United Arab Emirates
# 89574 2011-02-14 12:46:00       1.45     17829.0  United Arab Emirates
#
#              Date  Month  Year      Time
# 89570  2011-02-14      2  2011  12:46:00
# ...

# %%
As_data_d2=As_data2[(As_data2['Day']<=15)]
As_data_d2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# รวมทั้ง 2 เดือนเข้า ในช่วงตรุษจีน
Asia_data_chi=pd.concat([As_data_d,As_data_d2])
Asia_data_chi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-e3bc0e43340d> in <cell line: 2>()
#       1 # รวมทั้ง 2 เดือนเข้า ในช่วงตรุษจีน
# ----> 2 Asia_data_chi=pd.concat([As_data_d,As_data_d2])
#       3 Asia_data_chi
#
# NameError: name 'As_data_d' is not defined

# %%
chi= AS.groupby('InvoiceNo')['Description'].apply(list).reset_index()
chi

# %%
min_sup = 0.082
frequentItemsets_Asia= list(apriori(transactionsAsiaChi,min_support = min_sup))
for i in frequentItemsets_Asia:
    if i[0].__len__()>3:
        print('yes')
        print(i)
frequentItemsets_Asia

# %% [markdown]
# ## ข้อ 4 ของช่วงเวลา Chrhistmas & New Year ในทวีป Europe (1 Dec - 31 Dec)

# %%
Europe = [
    'Austria', 'Belgium', 'Channel Islands','Cyprus', 'Czech Republic', 'Denmark', 'EIRE',
    'European Community', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Italy',
    'Lithuania', 'Malta', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Spain', 'Sweden',
    'Switzerland', 'United Kingdom'
]

# %%
EU_data = data[data['Country']==""]
for i in range(len(Europe)):
  x = data[data['Country']==Europe[i]]
  EU_data=pd.concat([x,EU_data])
EU_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 536964    581232   15056BL              EDWARDIAN PARASOL BLACK        24
# 536965    581232    15056P               EDWARDIAN PARASOL PINK        12
# 536966    581232     22059        CERAMIC STRAWBERRY DESIGN MUG        24
# 536967    581232     22646   CERAMIC STRAWBERRY CAKE MONEY BANK        36
# 536968    581232      POST                              POSTAGE         4
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# ...

# %%
Eu_data=EU_data[(EU_data['Month']==12)]
Eu_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010-12-01
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010-12-01
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
#
#    Month  Year      Time  Day
# 0     12  2010  08:26:00    1
# 1     12  2010  08:26:00    1
# ...

# %%
Eu_data_d=Eu_data[(Eu_data['Day']<=31)]
Eu_data_d.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010-12-01
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010-12-01
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
#
#    Month  Year      Time  Day
# 0     12  2010  08:26:00    1
# 1     12  2010  08:26:00    1
# ...

# %%
transactionsEU= Eu_data_d.groupby('InvoiceNo')['Description'].apply(list).reset_index()
#
transactionsEU
# Out:
#      InvoiceNo                                        Description
# 0       536365  [WHITE HANGING HEART T-LIGHT HOLDER, WHITE MET...
# 1       536366  [HAND WARMER UNION JACK, HAND WARMER RED POLKA...
# 2       536367  [ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHO...
# 3       536368  [JAM MAKING SET WITH JARS, RED COAT RACK PARIS...
# 4       536369                         [BATH BUILDING BLOCK WORD]
# ...        ...                                                ...
# 3022   C581484                      [PAPER CRAFT , LITTLE BIRDIE]
# 3023   C581490  [VICTORIAN GLASS HANGING T-LIGHT, ZINC T-LIGHT...
# 3024   C581499                                           [Manual]
# 3025   C581568                       [VICTORIAN SEWING BOX LARGE]
# 3026   C581569  [HANGING HEART JAR T-LIGHT HOLDER, 36 PENCILS ...
#
# [3027 rows x 2 columns]

# %%
min_sup =0.08
frequentItemsetsEU= list(apriori(transactionsEU,min_support = min_sup))
for i in frequentItemsetsEU:
    if i[0].__len__()>3:
        print('yes')
        print(i)
frequentItemsetsEU
# Out:
# yes
# ...

# %%
set(data[(data['StockCode']=='85123A') | (data['StockCode']=='22086')]['Description'])
# Out:
# {'?',
#  'CREAM HANGING HEART T-LIGHT HOLDER',
#  "PAPER CHAIN KIT 50'S CHRISTMAS ",
#  'WHITE HANGING HEART T-LIGHT HOLDER',
#  'wrongly marked carton 22804'}

# %% [markdown]
# ##ข้อ 5. Valentine's day

# %%
Valen_data = data[(data['Month']==2)]
Valen_data

# %%
Valen_data = data[(data['Month']==2)]
Valen_data

# %%
transactions_valen = valen_day.groupby('InvoiceNo')['StockCode'].apply(list)
len(transactions_valen)

# %%
min_sup = 0.09
frequentItemsets_valen= list(apriori(transactions_valen,min_support = min_sup))
for i in frequentItemsets_valen:
    if i[0].__len__()>1:
        print('yes')
        print(i)
frequentItemsets_valen

# %%
len(frequentItemsets_valen)

# %%
set(data[(data['StockCode']=='20725')|(data['StockCode']=='22720')]['Description'])

# %% [markdown]
# - SET OF 3 CAKE TINS PANTRY DESIGN  มีค่า 14.5 % มีมากที่สุดจากทั้งหมด 18 อัน ที่ค่า min sup 0.08

# %% [markdown]
# ##ข้อ6. โดยจัดกลุ่มตามประเทศ groupby ประเทศ - เดือน

# %%
data

# %%
trans_CM = data.groupby(['Country','Month'])['Description'].apply(list).reset_index()
trans_Country_M = trans_CM['Description'].apply(lambda x: [str(item) for item in x])
trans_Country_M

# %%
min_sup = 0.31

frequentItemset_CM = list(apriori(trans_Country_M, min_support = min_sup))
for i in frequentItemset_CM:
    if i[0].__len__()>1:
        print('yes')
        print(i)

# %% [markdown]
# - มี 2 itemset ที่ผ่าน 0.31
# 1. คนที่ซื้อทั้ง POSTAGE และ ROUND SNACK BOXES SET OF4 WOODLAND จาก dataset ทั้งหมด มี 32.09%
#
#    คนที่ซื้อ POSTAGE และ ROUND SNACK BOXES SET OF4 WOODLAN มี 32.09%
#
#    คนที่ซื้อ POSTAGE แล้วค่อยซื้อ ROUND SNACK BOXES SET OF4 WOODLAND มี 55.88%
#
#    คนที่ซื้อ ROUND SNACK BOXES SET OF4 WOODLAND แล้วค่อยซื้อ POSTAGE มี 84.07%
